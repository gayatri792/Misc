# %%
class chatbot(object):
    def __init__(self):
        print('Hi, Welcome to Hotel Transalvaniya!!')
        print('\n')
        print('What do you prefer??')
        print('\n')
        print('BOOK A STAY')
        print('OR')
        print('HOLD A TABLE')
        
    def stay():
            while True:
                print('Choose which type of stay you prefer')
                print(' 1. Single Bedroom \n 2. Two-Sharing Bedroom \n 3. Double Bedroom w/o pool \n 4. Double Bedroom with PvtPool \n 5. Family Bedroom for 4')

        
                room_type = {'1':'Single Bedroom',
                     '2':'Two-Sharing Bedroom',
                     '3':'Double Bedroom w/o pool',
                     '4':'Double Bedroom with PvtPool',
                     '5':'Family Bedroom for 4'}
         
                price_day = {'Single Bedroom': '$1000',
                     'Two-Sharing Bedroom' : '$2000',
                     'Double Bedroom w/o pool' : '$2500',
                     'Double Bedroom with PvtPool' : '$3000',
                     'Family Bedroom for 4' : '5000'}
        
                x = input('Please enter the number : ')
                print('\n')
                print(f'That will be {price_day[room_type[x]]} per day')
                
                y = input('Please enter Y to book or N to go back : ')
                if (y[0].lower() == 'y'):
                    name = input('Enter your name :')
                    contact = input('Enter your contact num :')
                    return(f'Thank You!!! \n\n Your booking is confirmed!!!! \n\n Hai, {name} welcome to Hotel Transylvania') 
                
                    
    def table():
        while True:
            slot = {  '1' : 'italian',
                      '2' : 'arabic',
                      '3' : 'indian',
                      '4' : 'chineese'}
            
            price = { 'italian' : '$50',
                      'arabic' : '$60',
                      'indian' : '$100',
                      'chineese' : '$100'}
            
            a = input('Do you want Dinner or Lunch?? : ')
            if (a[0].lower() == 'l'):
                print('Buffet Lunch at $50 per person')
            else:
                b = input('Do you prefer Buffet or "La Carte" : ')
                if ((a[0].lower() == 'd') & (b[0].lower()== 'l')):
                    print('\n')
                    print(' 1 : Italian \n 2 : Arabic \n 3 : Indian \n 4 : Chineese')
                    s = input('Please select the type of Cuisine you prefer :')
                    print('\n')
                    print(f'That will be {price[slot[s]]} per person')
                    
                if ((a[0].lower() == 'd') & (b[0].lower()== 'b')):
                    print('\n')
                    print('Buffet Lunch at $80 per person')
                    
            y = input('Please enter Y to book or N to go back : ')
            if (y.lower() == 'y'):
                name = input('Enter your name :')
                contact = input('Enter your contact num :')
                return print(f'Thank You!!! \n\n Your booking is confirmed!!!! \n\n Hai, {name} welcome to Hotel Transylvania') 
            else:
                True

# %%
def MyChatbot():
    while True:
        ch = chatbot()
        ch = chatbot
        q = input('Enter your Choice : ')
        if (q[0].lower()=='s'):
            ch.stay()
        elif (q[0].lower()=='t'):
            ch.table()
        t = input('Do you want to continue? Y/N : ')
        if (t[0].lower()=='n'):
            return print('Have a good day!!')
        else:
            True

# %%
MyChatbot()
# Out:
# Hi, Welcome to Hotel Transalvaniya!!
#
#
# What do you prefer??
#
#
# BOOK A STAY
# OR
# HOLD A TABLE
# Enter your Choice : v
# Do you want to continue? Y/N : y
# Hi, Welcome to Hotel Transalvaniya!!
#
#
# What do you prefer??
#
#
# BOOK A STAY
# OR
# HOLD A TABLE
# Enter your Choice : s
# Choose which type of stay you prefer
#  1. Single Bedroom
#  2. Two-Sharing Bedroom
#  3. Double Bedroom w/o pool
#  4. Double Bedroom with PvtPool
#  5. Family Bedroom for 4
# Please enter the number : 5
#
#
# That will be 5000 per day
# Please enter Y to book or N to go back : n
# Choose which type of stay you prefer
#  1. Single Bedroom
#  2. Two-Sharing Bedroom
#  3. Double Bedroom w/o pool
#  4. Double Bedroom with PvtPool
#  5. Family Bedroom for 4
# Please enter the number : 6
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-6f4d888a9700> in <module>
# ...
